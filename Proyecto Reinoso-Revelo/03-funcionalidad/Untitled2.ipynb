# %%
from tkinter import *    # Carga módulo tk (widgets estándar)
from tkinter import ttk  # Carga ttk (para widgets nuevos 8.5+)
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk,Image
import sys
from tkinter import filedialog as fd

class Aplicacion():
    def __init__(self):
        self.inicio = tk.Tk()
        self.inicio.geometry('350x500') # anchura x altura
        self.inicio.title('')

        image2 = Image.open("/home/dev-16/Documentos/Universidad/Python-Revelo-Karla/py-revelo-herrera-karla-michelle/fondo.png")        
        image1 = ImageTk.PhotoImage(image2)                
        background_label = Label(self.inicio, image=image1)
        background_label.image=image1
        background_label.place(x=0, y=0, height=500, width=500)        

        fontStyle = tkFont.Font(family="Arial", size=12)

        self.botonCargar = tk.Button(self.inicio, text='CARGAR IMAGEN', font=fontStyle, bg = '#22201C', fg = 'white',
                 height = 5, width=60, command= abrir_imagen).pack(side=BOTTOM)

        self.inicio.mainloop()
def main():
    mi_app = Aplicacion()
    return 0

if __name__ == '__main__':
    main()
# Out:
# hola
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/ImageFile.py", line 496, in _save
#     fh = fp.fileno()
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dev-16/anaconda3/lib/python3.7/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-21-7cac830d686a>", line 14, in corte_cuadrado
#     area_recortada.show()
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/Image.py", line 2146, in show
#     _show(self, title=title, command=command)
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/Image.py", line 3085, in _show
#     _showxv(image, **options)
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/Image.py", line 3091, in _showxv
#     ImageShow.show(image, title, **options)
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/ImageShow.py", line 48, in show
#     if viewer.show(image, title=title, **options):
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/ImageShow.py", line 68, in show
#     return self.show_image(image, **options)
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/ImageShow.py", line 88, in show_image
#     return self.show_file(self.save_image(image), **options)
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/ImageShow.py", line 84, in save_image
#     return image._dump(format=self.get_format(image), **self.options)
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/Image.py", line 611, in _dump
#     self.save(filename, format, **options)
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/Image.py", line 2102, in save
#     save_handler(self, fp, filename)
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/PngImagePlugin.py", line 900, in _save
#     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#   File "/home/dev-16/anaconda3/lib/python3.7/site-packages/PIL/ImageFile.py", line 504, in _save
#     e.setimage(im.im, b)
# SystemError: tile cannot extend outside image

# %%
from tkinter import *    # Carga módulo tk (widgets estándar)
from tkinter import ttk  # Carga ttk (para widgets nuevos 8.5+)
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk,Image
import sys
from tkinter import filedialog as fd

def dimensiones():
        print('hola')
        pantallaDimensiones = tk.Tk()
        pantallaDimensiones.geometry('400x500') 
        pantallaDimensiones.title('')
        pantallaDimensiones.configure(bg = 'white')
        #fondo=PhotoImage(file= "/home/dev-16/Documentos/Universidad/Python-Revelo-Karla/py-revelo-herrera-karla-michelle/perrito.png")        
        #fondo.configure(height = 400, width = 400)
        #lblFondo=Label(pantallaDimensiones,image=fondo).place(x=0,y=50) #fondo 
        fontStyle = tkFont.Font(family="Arial", size=1)        
        botonAtras = tk.Button(pantallaDimensiones, text='ATRAS', font=fontStyle, bg = 'white', fg = 'black',
                  height = 2, width=10, command= pantallaDimensiones.destroy).place(x=0, y=0)    
        botonCortar = tk.Button(pantallaDimensiones, text='CORTAR', font=fontStyle, bg = 'white', fg = 'black',
             height = 2, width=20, command=cortar).place(x=0, y=460)
        botonRotar = tk.Button(pantallaDimensiones, text='ROTAR', font=fontStyle, bg = 'white', fg = 'black',
             height = 2, width=20).place(x=200, y=460)    
        pantallaDimensiones.mainloop()

# %%
from tkinter import *    # Carga módulo tk (widgets estándar)
from tkinter import ttk  # Carga ttk (para widgets nuevos 8.5+)
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk,Image
import sys
from tkinter import filedialog as fd

def abrir_imagen():
        #nombrearch=fd.askopenfilename(initialdir = "/",title = "Seleccione archivo",filetypes = (("png files","*.png"),("todos los archivos","*.*")))    
        #if nombrearch!='':      
        pantallaPrincipal = tk.Tk()
        pantallaPrincipal.geometry('400x500') 
        pantallaPrincipal.title('')
        pantallaPrincipal.configure(bg = 'white')
        #img = Image.open("/home/dev-16/Documentos/Universidad/Python-Revelo-Karla/py-revelo-herrera-karla-michelle/perrito.png")    
        imgen = PhotoImage(file = "/home/dev-16/Documentos/Universidad/Python-Revelo-Karla/py-revelo-herrera-karla-michelle/perrito.pgm")
        widget = Label(ventana, image=img).pack()
        #label=Label(pantallaPrincipal,image=ph).place(x=0,y=50) #fondo 
        #label.image=ph        
        fontStyle = tkFont.Font(family="Helvetica", size=2, weight = 'bold')
        botonInicio = tk.Button(pantallaPrincipal, text='INICIO', font=fontStyle, bg = 'white', fg = 'black',
                  height = 2, width=10, command = pantallaPrincipal.destroy).place(x=0, y=0)
        botonGuardar = tk.Button(pantallaPrincipal, text='GUARDAR', font=fontStyle, bg = 'white', fg = 'black',
                  height = 2, width=10).place(x=280, y=0)
        botonDimensiones = tk.Button(pantallaPrincipal, text='DIMENSIONES', font=fontStyle, bg = 'white', fg = 'black',
                  height = 2, width=10, command = dimensiones).place(x=0, y=460)
        botonTexto = tk.Button(pantallaPrincipal, text='TEXTO', font=fontStyle, bg = 'white', fg = 'black',
                  height = 2, width=4).place(x=120, y=460)
        botonEfectos = tk.Button(pantallaPrincipal, text='EFECTOS', font=fontStyle, bg = 'white', fg = 'black',
                  height = 2, width=5).place(x=187, y=460)
        botonSuperpo = tk.Button(pantallaPrincipal, text='SUPERPOSICION', font=fontStyle, bg = 'white', fg = 'black',
                  height = 2, width=12).place(x=263, y=460)

# %%
from tkinter import *    # Carga módulo tk (widgets estándar)
from tkinter import ttk  # Carga ttk (para widgets nuevos 8.5+)
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk,Image
import sys
from tkinter import filedialog as fd

def cortar():
    #nombrearch=fd.askopenfilename(initialdir = "/",title = "Seleccione archivo",filetypes = (("png files","*.png"),("todos los archivos","*.*")))    
    #if nombrearch!='':      
    pantallaCorte = tk.Tk()
    pantallaCorte.geometry('400x500') 
    pantallaCorte.title('')
    pantallaCorte.configure(bg = 'white')
    #fondo=PhotoImage(file= "/home/dev-16/Documentos/Universidad/Python-Revelo-Karla/py-revelo-herrera-karla-michelle/perrito.png")        
    #fondo.configure(height = 400, width = 400)
    #lblFondo=Label(pantallaPrincipal,image=fondo).place(x=0,y=50) #fondo 
    fontStyle = tkFont.Font(family="Arial", size=2, weight = 'bold')
    botonAtras = tk.Button(pantallaCorte, text='ATRAS', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=10, command = pantallaCorte.destroy).place(x=0, y=0)
    botonAceptar = tk.Button(pantallaCorte, text='ACEPTAR', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=10).place(x=280, y=0)
    corteCuadrado = tk.Button(pantallaCorte, text='CUADRADO', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=10, command = corte_cuadrado).place(x=0, y=460)
    corte1 = tk.Button(pantallaCorte, text='4:3', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=8).place(x=120, y=460)
    corte2 = tk.Button(pantallaCorte, text='3:2', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=8).place(x=210, y=460)
    corte3 = tk.Button(pantallaCorte, text='16:9', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=8).place(x=305, y=460)

# %%
from tkinter import *    # Carga módulo tk (widgets estándar)
from tkinter import ttk  # Carga ttk (para widgets nuevos 8.5+)
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk,Image
import sys
from tkinter import filedialog as fd

def corte_cuadrado():
    imagen = Image.open("/home/dev-16/Documentos/Universidad/Python-Revelo-Karla/py-revelo-herrera-karla-michelle/perrito.png")
    box = (50, 50, 50, 50)
    area_recortada = imagen.crop(box)
    #img = ImageTk.PhotoImage(area_recortada)
    area_recortada.show()
    #panel = tk.Label(pantallaCorte, image = img)
    #panel.pack(side = "bottom", fill = "both", expand = "yes")
