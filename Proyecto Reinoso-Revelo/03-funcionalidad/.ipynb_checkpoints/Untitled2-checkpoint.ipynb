# %%
from tkinter import *    # Carga módulo tk (widgets estándar)
from tkinter import ttk  # Carga ttk (para widgets nuevos 8.5+)
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk,Image
import sys
from tkinter import filedialog as fd

class Aplicacion():
    def __init__(self):
        inicio = tk.Tk()
        inicio.geometry('350x500') # anchura x altura
        inicio.title('')

        image2 = Image.open("/home/dev-16/Documentos/Universidad/Python-Revelo-Karla/py-revelo-herrera-karla-michelle/fondo.png")
        #image2.show()
        image1 = ImageTk.PhotoImage(image2)
        background_label = tk.Label(inicio, image=image1)
        background_label.image1=image1
        background_label.place(x=0, y=0, height=500, width=500)

        fontStyle = tkFont.Font(family="Arial", size=12)

        tk.Button(inicio, text='CARGAR IMAGEN', font=fontStyle, bg = '#22201C', fg = 'white',
                 height = 5, width=60, command=abrir_imagen).pack(side=BOTTOM)

        inicio.mainloop()
        
def main():
    mi_app = Aplicacion()
    return 0

if __name__ == '__main__':
    main()

# %%
from tkinter import *    # Carga módulo tk (widgets estándar)
from tkinter import ttk  # Carga ttk (para widgets nuevos 8.5+)
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk,Image
import sys
from tkinter import filedialog as fd

def dimensiones():
        print('hola')
        pantallaDimensiones = tk.Tk()
        pantallaDimensiones.geometry('350x500') 
        pantallaDimensiones.title('')
        pantallaDimensiones.configure(bg = 'white')
        #fondo=PhotoImage(file= "/home/dev-16/Documentos/Universidad/Python-Revelo-Karla/py-revelo-herrera-karla-michelle/perrito.png")        
        #fondo.configure(height = 400, width = 400)
        #lblFondo=Label(pantallaDimensiones,image=fondo).place(x=0,y=50) #fondo 
        fontStyle = tkFont.Font(family="Arial", size=0)
        tk.Button(pantallaDimensiones, text='ATRAS', font=fontStyle, bg = 'white', fg = 'black',
                  height = 2, width=10, command= pantallaDimensiones.destroy).place(x=0, y=0)    
        tk.Button(pantallaDimensiones, text='CORTAR', font=fontStyle, bg = 'white', fg = 'black',
             height = 2, width=15).place(x=0, y=460)
        tk.Button(pantallaDimensiones, text='ROTAR', font=fontStyle, bg = 'white', fg = 'black',
             height = 2, width=15).place(x=140, y=460)    
        pantallaDimensiones.mainloop()

# %%
from tkinter import *    # Carga módulo tk (widgets estándar)
from tkinter import ttk  # Carga ttk (para widgets nuevos 8.5+)
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk,Image
import sys
from tkinter import filedialog as fd

def abrir_imagen():
    #nombrearch=fd.askopenfilename(initialdir = "/",title = "Seleccione archivo",filetypes = (("png files","*.png"),("todos los archivos","*.*")))    
    #if nombrearch!='':      
    pantallaPrincipal = tk.Tk()
    pantallaPrincipal.geometry('350x500') 
    pantallaPrincipal.title('')
    pantallaPrincipal.configure(bg = 'white')
    #fondo=PhotoImage(file= "/home/dev-16/Documentos/Universidad/Python-Revelo-Karla/py-revelo-herrera-karla-michelle/perrito.png")        
    #fondo.configure(height = 400, width = 400)
    #lblFondo=Label(pantallaPrincipal,image=fondo).place(x=0,y=50) #fondo 
    fontStyle = tkFont.Font(family="Arial", size=1)
    tk.Button(pantallaPrincipal, text='INICIO', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=10, command = pantallaPrincipal.destroy).place(x=0, y=0)
    tk.Button(pantallaPrincipal, text='GUARDAR', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=10).place(x=220, y=0)
    tk.Button(pantallaPrincipal, text='DIMENSIONES', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=10, command = dimensiones).place(x=0, y=460)
    tk.Button(pantallaPrincipal, text='TEXTO', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=4).place(x=120, y=460)
    tk.Button(pantallaPrincipal, text='EFECTOS', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=4).place(x=190, y=460)
    tk.Button(pantallaPrincipal, text='SUPERPOSICION', font=fontStyle, bg = 'white', fg = 'black',
              height = 2, width=10).place(x=250, y=460)
    pantallaPrincipal.mainloop()
